# %%
import numpy as np

# %%
X = 2*np.random.rand(1,100) # Gives the random number between 0 and 1

# %%
X.shape
X.size
# Out:
# 100

# %%
y = 4 + 3*np.random.randn(100) # Give the random number that gives gaussion distribution

# %% [markdown]
# ## Visualization (Histogram)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(y, bins =30 , density =True , alpha = 0.6 , color = "green")
plt.show()

# %%
sns.kdeplot(y, fill = True , color = "skyblue")
# Out:
# <Axes: ylabel='Density'>
