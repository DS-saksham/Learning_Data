# %%
# SVM tires to draw the best boundry that seperates differnt classes of data with the macimum possible
# distance(margin) between the classes. A bi

# %% [markdown]
# ### Important of Scaling the inputs when using SVMs

# %%
# SVM are sensitive to the scale of the features and unscaled data can lead to poor performacne
# and wrong result . SVMs calculate distance between data points to find the best boundarty and 
# if one value is small and other is large then the larger value will dominate

# %%
# Scaling ensures fair contribution form all features Common method for scaling:: Min_max scaling, Standardization (Z_score

# %% [markdown]
# ### Can SVM classifer output a confidence score  when it classifies an instance

# %%
# The distance form the seperating hyperplan is often usef as a confidence score.
# The further a point is form the hyperplane the more confidence the SVM is in the prediction

# %% [markdown]
# ## Primal and Dual form of SVm

# %%
# They are the two different mathematical formulations or perspectives of solving the same 
# optimization problem behild an SVM

# %% [markdown]
# ### Primal form of SVM

# %%
# This is the original version of the optimization problem where we directy optimize the weight and the bias
